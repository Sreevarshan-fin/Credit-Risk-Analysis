# %% [markdown]
# <h1 align='center' style='color:blue'> Credit Risk Modeling Project</h1>

# %% [markdown]
# **Problem Statement**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

warnings.filterwarnings('default')



pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load Data

# %%
df_customers = pd.read_csv("dataset/customers.csv")
df_loans = pd.read_csv("dataset/loans.csv")
df_bureau = pd.read_csv("dataset/bureau_data.csv")

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001

# %%
df_loans.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
df = pd.merge(df_customers, df_loans, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df = pd.merge(df, df_bureau, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.default.value_counts()
# Out:
# default
# False    45703
# True      4297
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# **The target variable default is clearly imbalanced — about 92% of customers did not default, while only around 8% did. This imbalance can push the model to favor the majority class, so I’ll handle it later using methods like class weights or SMOTE to ensure the model learns both classes properly**

# %% [markdown]
# ### Train Test split

# %% [markdown]
# **Performing train test split before doing EDA to prevent data leakage. I don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.**

# %%
X = df.drop("default", axis="columns")
y = df['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train = pd.concat([X_train, y_train], axis="columns")
df_test = pd.concat([X_test, y_test], axis="columns")

df_train.head(2)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
#
#        default
# 12746        0
# 32495        0
#
# [2 rows x 33 columns]

# %% [markdown]
# <h3 align="center" style="color:blue">Data Cleaning</h3>

# %% [markdown]
# ### Handle Missing & Duplicate Values

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence = df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence, inplace=True)
df_test.residence_type.fillna(mode_residence, inplace=True)

df_train.residence_type.unique(), df_test.residence_type.unique()
# Out:
# C:\Users\sree varshan\AppData\Local\Temp\ipykernel_9796\2805913581.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train.residence_type.fillna(mode_residence, inplace=True)
# C:\Users\sree varshan\AppData\Local\Temp\ipykernel_9796\2805913581.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test.residence_type.fillna(mode_residence, inplace=True)
# (array(['Owned', 'Mortgage', 'Rented'], dtype=object),
#  array(['Owned', 'Mortgage', 'Rented'], dtype=object))

# %%
df_train['loan_purpose'] = df_train['loan_purpose'].replace('Personaal', 'Personal')
df_train['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# std   169035.02       6257832.98   5371862.29       113128.14  966935.21
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1142000.00    961000.00        19220.00  172980.00
# 50%   400001.00       2644000.00   2230000.00        44600.00  401400.00
# 75%   560001.00       5178000.00   4619000.00        92420.00  831420.00
# max   700001.00      52175000.00  47819000.00      5293543.52 8607420.00
#
#        net_disbursement  ...  principal_outstanding  \
# count          37500.00  ...               37500.00
# mean         3196854.19  ...             1333819.51
# std          4297489.83  ...             1213674.44
# min                0.00  ...                  -1.00
# 25%           768800.00  ...              422197.50
# 50%          1784000.00  ...              997427.50
# 75%          3695200.00  ...             1784879.00
# max         38255200.00  ...             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     37500.00                 37500.00
# mean                     986298.87                     2.50
# std                     1043145.01                     1.12
# min                           0.00                     1.00
# 25%                      287040.25                     1.00
# 50%                      665014.50                     3.00
# 75%                     1234062.75                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   37500.00           37500.00           37500.00
# mean                        1.00              76.11               4.84
# std                         0.81              43.77               5.84
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               8.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio  default
# count   37500.00       37500.00                  37500.00 37500.00
# mean       26.67           5.01                     43.42     0.09
# std        32.78           2.03                     29.39     0.28
# min         0.00           1.00                      0.00     0.00
# 25%         0.00           4.00                     18.00     0.00
# 50%        13.00           5.00                     39.00     0.00
# 75%        46.00           6.00                     67.00     0.00
# max       171.00           9.00                     99.00     1.00
#
# [8 rows x 21 columns]

# %% [markdown]
# <h3 style="color:blue" align="center">Exploratory Data Analysis</h3>

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### Box plot to visualize outliers

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.savefig('Outliers Detection.PNG')
plt.tight_layout()
plt.show()
# Out:
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\seaborn\categorical.py:700: PendingDeprecationWarning: vert: bool will be deprecated in a future version. Use orientation: {'vertical', 'horizontal'} instead.
#   artists = ax.bxp(**boxplot_kws)

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')
plt.savefig('Distribution plot of continous value.PNG')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test.residence_type.isna().sum()
# Out:
# np.int64(0)

# %%
# Apply same step on test set
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# No rows found that breaks rule 1 and rule 2

# %% [markdown]
# ### Analyze Categorical Columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# ## **Distributional analysis of numerical variables using KDE plots across target classes.**

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %% [markdown]
# ### Age Column

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all the Columns

# %%
plt.figure(figsize=(30, 28), dpi=120)  

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)

    sns.kdeplot(
        df_train_1.loc[df_train_1['default'] == 0, col],
        color='green',
        linewidth=2,
        label='Non-default (0)',
        common_norm=False
    )

    sns.kdeplot(
        df_train_1.loc[df_train_1['default'] == 1, col],
        color='red',
        linewidth=2,
        label='Default (1)',
        common_norm=False
    )

   
    plt.title(col, fontsize=12, fontweight='bold')
    plt.xlabel(col, fontsize=7)
    plt.ylabel('Density', fontsize=7)


    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)

    plt.legend(fontsize=7)
    
plt.savefig("kde_plot_4.png")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# <h3 style="color:blue" align="center">Feature Engineering, Feature Selection</h3>

# %% [markdown]
# #### Generate Loan to Income (LTI) Ratio

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'],2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.00
# mean        1.56
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.46
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# #### Generate Delinquency Ratio

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# #### Generate Avg DPD Per Delinquency

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %%
df_train_1
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
# ...       ...  ...    ...            ...               ...       ...
# 28515  C28516   70      M         Single     Self-Employed   2470000
# 5558   C05559   39      F         Single          Salaried   2472000
# 45236  C45237   39      M        Married     Self-Employed   1329000
# 49228  C49229   33      M         Single          Salaried   1274000
# 37784  C37785   31      F         Single          Salaried   8622000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
# ...                     ...            ...                       ...
# 28515                     0          Owned                        20
# 5558                      0         Rented                        26
# 45236                     4          Owned                        10
# 49228                     2          Owned                        26
# 37784                     1         Rented                         8
#
#             city  ... number_of_closed_accounts  total_loan_months  \
# 12746  Hyderabad  ...                         2                152
# 32495     Mumbai  ...                         1                160
# 43675    Chennai  ...                         1                 54
# 9040   Bangalore  ...                         0                 76
# 13077       Pune  ...                         2                 60
# ...          ...  ...                       ...                ...
# 28515    Kolkata  ...                         0                 40
# 5558     Kolkata  ...                         0                 52
# 45236       Pune  ...                         2                130
# 49228    Chennai  ...                         1                 88
# 37784     Mumbai  ...                         0                 17
#
#       delinquent_months total_dpd enquiry_count  credit_utilization_ratio  \
# 12746                20       118             4                        36
# 32495                10        62             5                         5
# 43675                12        67             4                         0
# 9040                  0         0             8                        87
# 13077                 0         0             1                        71
# ...                 ...       ...           ...                       ...
# 28515                 0         0             5                        13
# 5558                 14        72             4                        44
# 45236                11        44             6                        97
# 49228                 0         0             6                        25
# 37784                13        83             6                        95
#
#        default  loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746        0            2.07              13.20                     5.90
# 32495        0            1.61               6.20                     6.20
# 43675        0            3.54              22.20                     5.60
# 9040         0            1.13               0.00                     0.00
# 13077        0            0.50               0.00                     0.00
# ...        ...             ...                ...                      ...
# 28515        0            0.57               0.00                     0.00
# 5558         0            1.11              26.90                     5.10
# 45236        1            3.37               8.50                     4.00
# 49228        0            1.48               0.00                     0.00
# 37784        1            0.84              76.50                     6.40
#
# [37488 rows x 36 columns]

# %%
df_train_1
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
# ...       ...  ...    ...            ...               ...       ...
# 28515  C28516   70      M         Single     Self-Employed   2470000
# 5558   C05559   39      F         Single          Salaried   2472000
# 45236  C45237   39      M        Married     Self-Employed   1329000
# 49228  C49229   33      M         Single          Salaried   1274000
# 37784  C37785   31      F         Single          Salaried   8622000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
# ...                     ...            ...                       ...
# 28515                     0          Owned                        20
# 5558                      0         Rented                        26
# 45236                     4          Owned                        10
# 49228                     2          Owned                        26
# 37784                     1         Rented                         8
#
#             city  ... number_of_closed_accounts  total_loan_months  \
# 12746  Hyderabad  ...                         2                152
# 32495     Mumbai  ...                         1                160
# 43675    Chennai  ...                         1                 54
# 9040   Bangalore  ...                         0                 76
# 13077       Pune  ...                         2                 60
# ...          ...  ...                       ...                ...
# 28515    Kolkata  ...                         0                 40
# 5558     Kolkata  ...                         0                 52
# 45236       Pune  ...                         2                130
# 49228    Chennai  ...                         1                 88
# 37784     Mumbai  ...                         0                 17
#
#       delinquent_months total_dpd enquiry_count  credit_utilization_ratio  \
# 12746                20       118             4                        36
# 32495                10        62             5                         5
# 43675                12        67             4                         0
# 9040                  0         0             8                        87
# 13077                 0         0             1                        71
# ...                 ...       ...           ...                       ...
# 28515                 0         0             5                        13
# 5558                 14        72             4                        44
# 45236                11        44             6                        97
# 49228                 0         0             6                        25
# 37784                13        83             6                        95
#
#        default  loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746        0            2.07              13.20                     5.90
# 32495        0            1.61               6.20                     6.20
# 43675        0            3.54              22.20                     5.60
# 9040         0            1.13               0.00                     0.00
# 13077        0            0.50               0.00                     0.00
# ...        ...             ...                ...                      ...
# 28515        0            0.57               0.00                     0.00
# 5558         0            1.11              26.90                     5.10
# 45236        1            3.37               8.50                     4.00
# 49228        0            1.48               0.00                     0.00
# 37784        1            0.84              76.50                     6.40
#
# [37488 rows x 36 columns]

# %%
columns_continuous_2 = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio','loan_to_income','delinquency_ratio','avg_dpd_per_delinquency']

# %%
columns_continuous_2
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %%
plt.figure(figsize=(30, 28), dpi=120)  

for i, col in enumerate(columns_continuous_2):
    plt.subplot(6, 4, i+1)

    sns.kdeplot(
        df_train_1.loc[df_train_1['default'] == 0, col],
        color='green',
        linewidth=2,
        label='Non-default (0)',
        common_norm=False
    )

    sns.kdeplot(
        df_train_1.loc[df_train_1['default'] == 1, col],
        color='red',
        linewidth=2,
        label='Default (1)',
        common_norm=False
    )

   
    plt.title(col, fontsize=12, fontweight='bold')
    plt.xlabel(col, fontsize=7)
    plt.ylabel('Density', fontsize=7)


    plt.xticks(fontsize=7)
    plt.yticks(fontsize=7)

    plt.legend(fontsize=7)
    
plt.savefig("kde_plot_5.png")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# ### Remove columns that business contact person asked us to remove
#
# - Based on the analysis and domain research conducted, these columns were dropped in accordance with business rules and domain constraints.
#
# - Post-disbursal variables such as delinquency and DPD introduce data leakage, as they are not available at decision time.
#
# - Date fields and sensitive attributes like income and loan amount were excluded to ensure regulatory compliance, fairness, and production stability.

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %% [markdown]
# #### Same transformation on test set

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head(2)
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 12746     0.66  ...               0.42                  1.00
# 32495     0.49  ...               0.83                  0.09
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
#
# [2 rows x 26 columns]

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# d:\AI_Course\Data science\Data science_PB\mlenv\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.70
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.80
# 4               sanction_amount 101.09
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.18
# 9         principal_outstanding  16.33
# 10  bank_balance_at_application   9.34
# 11      number_of_open_accounts   4.39
# 12    number_of_closed_accounts   2.38
# 13                enquiry_count   6.41
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.96
# 16            delinquency_ratio   1.93
# 17      avg_dpd_per_delinquency   2.91

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
calculate_vif(X_train_1[numeric_columns])
# Out:
#                          Column  VIF
# 0                           age 5.43
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.40
# 3                       zipcode 3.78
# 4            loan_tenure_months 6.02
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.35
# 7     number_of_closed_accounts 2.37
# 8                 enquiry_count 6.38
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.56
# 11            delinquency_ratio 1.93
# 12      avg_dpd_per_delinquency 2.91

# %%
selected_numeric_features_vif = vif_df.Column.values
selected_numeric_features_vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 selected_numeric_features_vif = vif_df.Column.values
#       2 selected_numeric_features_vif
#
# NameError: name 'vif_df' is not defined

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Selection: Categorical Features

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746     0.66  ...    Secured               0.42
# 32495     0.49  ...    Secured               0.83
# 43675     0.83  ...    Secured               0.49
# 9040      0.76  ...    Secured               0.64
# 13077     0.51  ...  Unsecured               0.17
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
# 43675                         0.17                     0.00
# 9040                          0.08                     0.67
# 13077                         0.07                     0.00
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
# 43675                       0.50           0.38                      0.00
# 9040                        0.00           0.88                      0.88
# 13077                       1.00           0.00                      0.72
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
# 43675            0.76               0.22                     0.56
# 9040             0.19               0.00                     0.00
# 13077            0.05               0.00                     0.00
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Calculate WOE and IV

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  float64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income               37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': np.float64(0.0890689462679479),
#  'gender': np.float64(0.00047449502170914947),
#  'marital_status': np.float64(0.001129766845390142),
#  'employment_status': np.float64(0.003953046301722585),
#  'number_of_dependants': np.float64(0.0019380899135053508),
#  'residence_type': np.float64(0.246745268718145),
#  'years_at_current_address': np.float64(0.0020800513608156363),
#  'city': np.float64(0.0019059578709781529),
#  'state': np.float64(0.0019005589806779287),
#  'zipcode': np.float64(0.0016677413243392572),
#  'loan_purpose': np.float64(0.3691197842282755),
#  'loan_type': np.float64(0.16319324904149224),
#  'loan_tenure_months': np.float64(0.21893515090196278),
#  'bank_balance_at_application': np.float64(0.0063187993277516365),
#  'number_of_open_accounts': np.float64(0.08463134083005877),
#  'number_of_closed_accounts': np.float64(0.0011964272592421567),
#  'enquiry_count': np.float64(0.007864214085342608),
#  'credit_utilization_ratio': np.float64(2.352965568168245),
#  'loan_to_income': np.float64(0.476415456948364),
#  'delinquency_ratio': np.float64(0.716576108689321),
#  'avg_dpd_per_delinquency': np.float64(0.40151905412190175)}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
# 9040  0.462               0.642                    0.667
# 13077 0.769               0.170                    0.000
# ...     ...                 ...                      ...
# 28515 1.000               0.113                    0.333
# 5558  0.404               0.491                    0.000
# 45236 0.404               0.604                    1.000
# 49228 0.288               0.585                    0.333
# 37784 0.250               0.396                    0.333
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
# 9040                      0.879           0.194              0.000
# 13077                     0.717           0.047              0.000
# ...                         ...             ...                ...
# 28515                     0.131           0.063              0.000
# 5558                      0.444           0.190              0.269
# 45236                     0.980           0.719              0.085
# 49228                     0.253           0.276              0.000
# 37784                     0.960           0.126              0.765
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
# 43675                    0.560                 False                  False
# 9040                     0.000                 False                  False
# 13077                    0.000                  True                  False
# ...                        ...                   ...                    ...
# 28515                    0.000                  True                  False
# 5558                     0.510                 False                   True
# 45236                    0.400                  True                  False
# 49228                    0.000                  True                  False
# 37784                    0.640                 False                   True
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
# 43675                   False               True                  False
# 9040                     True              False                  False
# 13077                   False              False                   True
# ...                       ...                ...                    ...
# 28515                   False              False                   True
# 5558                    False              False                  False
# 45236                   False               True                  False
# 49228                    True              False                  False
# 37784                   False              False                  False
#
#        loan_type_Unsecured
# 12746                False
# 32495                False
# 43675                False
# 9040                 False
# 13077                 True
# ...                    ...
# 28515                 True
# 5558                 False
# 45236                False
# 49228                False
# 37784                False
#
# [37488 rows x 13 columns]

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
# 35347 0.365               0.755                    1.000
# 41814 0.577               0.717                    0.667
# ...     ...                 ...                      ...
# 29297 0.173               0.434                    0.667
# 20567 0.423               0.547                    0.000
# 681   0.192               0.170                    0.333
# 33682 0.250               0.585                    0.000
# 26116 0.385               0.321                    0.333
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
# 35347                     0.485           0.571              0.024
# 41814                     0.980           0.407              0.107
# ...                         ...             ...                ...
# 29297                     0.525           0.251              0.048
# 20567                     0.051           0.672              0.000
# 681                       0.545           0.002              0.062
# 33682                     0.859           0.785              0.000
# 26116                     0.919           0.087              0.214
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
# 30367                    0.000                  True                  False
# 35347                    0.700                  True                  False
# 41814                    0.640                 False                  False
# ...                        ...                   ...                    ...
# 29297                    0.280                  True                  False
# 20567                    0.000                 False                   True
# 681                      0.350                 False                   True
# 33682                    0.000                  True                  False
# 26116                    0.580                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
# 30367                   False              False                  False
# 35347                   False               True                  False
# 41814                   False               True                  False
# ...                       ...                ...                    ...
# 29297                   False              False                  False
# 20567                   False               True                  False
# 681                     False              False                   True
# 33682                   False               True                  False
# 26116                   False              False                   True
#
#        loan_type_Unsecured
# 19205                False
# 15514                False
# 30367                False
# 35347                False
# 41814                False
# ...                    ...
# 29297                False
# 20567                False
# 681                   True
# 33682                False
# 26116                 True
#
# [12497 rows x 13 columns]

# %% [markdown]
# <h3 align="center" style="color:blue">Model Training</h3>

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.71      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.97      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'saga', 'C': np.float64(3792.690190732246)}
# Best Score: 0.7578820896729832
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.7883672970285227
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.77      0.84      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.88      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.96      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.98      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.95      0.81     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34195
# 1    34195
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2025-12-28 17:31:37,321] A new study created in memory with name: no-name-dd54a4c7-46b1-4d3c-ae1e-cba8162d5108
# [I 2025-12-28 17:31:40,619] Trial 0 finished with value: 0.9302120042671689 and parameters: {'C': 0.01039962324912129, 'solver': 'newton-cg', 'tol': 3.0902406199295273e-06, 'class_weight': None}. Best is trial 0 with value: 0.9302120042671689.
# [I 2025-12-28 17:31:42,412] Trial 1 finished with value: 0.8592164996367112 and parameters: {'C': 31.368266488723002, 'solver': 'newton-cg', 'tol': 0.06792765340792309, 'class_weight': None}. Best is trial 0 with value: 0.9302120042671689.
# [I 2025-12-28 17:31:44,218] Trial 2 finished with value: 0.9442601210700531 and parameters: {'C': 1.983789593222121, 'solver': 'liblinear', 'tol': 0.05340518918138203, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9442601210700531.
# [I 2025-12-28 17:31:45,810] Trial 3 finished with value: 0.9382291995902978 and parameters: {'C': 1361.483814523078, 'solver': 'lbfgs', 'tol': 0.002547829340338972, 'class_weight': None}. Best is trial 2 with value: 0.9442601210700531.
# [I 2025-12-28 17:31:46,141] Trial 4 finished with value: 0.9456647572372227 and parameters: {'C': 6603.4418554352405, 'solver': 'newton-cg', 'tol': 2.9261063717345805e-05, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:46,328] Trial 5 finished with value: 0.9455770893228229 and parameters: {'C': 181.5804588807038, 'solver': 'lbfgs', 'tol': 0.00010661435271623074, 'class_weight': None}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:46,499] Trial 6 finished with value: 0.8356228307923006 and parameters: {'C': 0.0001570076259172192, 'solver': 'saga', 'tol': 0.0070829787503032034, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:46,750] Trial 7 finished with value: 0.9456351182207537 and parameters: {'C': 17.04053647985852, 'solver': 'newton-cg', 'tol': 8.628163155913119e-05, 'class_weight': None}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:46,837] Trial 8 finished with value: 0.7677715494269184 and parameters: {'C': 0.09576036827535885, 'solver': 'lbfgs', 'tol': 0.057207899784376536, 'class_weight': None}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:46,976] Trial 9 finished with value: 0.945474826476961 and parameters: {'C': 19.420735066162695, 'solver': 'saga', 'tol': 0.019799537228348877, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9456647572372227.
# [I 2025-12-28 17:31:47,257] Trial 10 finished with value: 0.9456794085990863 and parameters: {'C': 6444.05280066036, 'solver': 'liblinear', 'tol': 2.839995932211409e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:47,564] Trial 11 finished with value: 0.9456794085990863 and parameters: {'C': 8693.70498353491, 'solver': 'liblinear', 'tol': 1.9087167550233327e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:47,825] Trial 12 finished with value: 0.9456794085990863 and parameters: {'C': 4650.171825915325, 'solver': 'liblinear', 'tol': 3.048837199473617e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:48,089] Trial 13 finished with value: 0.9456794085990863 and parameters: {'C': 378.3328752012242, 'solver': 'liblinear', 'tol': 1.0467552959385002e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:48,358] Trial 14 finished with value: 0.9456794085990863 and parameters: {'C': 7801.074211740437, 'solver': 'liblinear', 'tol': 1.160571580307937e-05, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:48,593] Trial 15 finished with value: 0.9456355013159934 and parameters: {'C': 206.0469666420093, 'solver': 'liblinear', 'tol': 0.0005416563031453053, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:48,831] Trial 16 finished with value: 0.9444252060481556 and parameters: {'C': 0.5102735631723778, 'solver': 'liblinear', 'tol': 6.635655111921812e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:48,994] Trial 17 finished with value: 0.9052130245018501 and parameters: {'C': 0.0035551788186481644, 'solver': 'liblinear', 'tol': 1.3559772987813526e-06, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:49,240] Trial 18 finished with value: 0.9456794085990863 and parameters: {'C': 1047.2184115789416, 'solver': 'liblinear', 'tol': 2.6083863374211795e-05, 'class_weight': 'balanced'}. Best is trial 10 with value: 0.9456794085990863.
# [I 2025-12-28 17:31:49,518] Trial 19 finished with value: 0.9457804134639077 and parameters: {'C': 3.5336341730914653, 'solver': 'saga', 'tol': 0.0003167408538191622, 'class_weight': 'balanced'}. Best is trial 19 with value: 0.9457804134639077.
# [I 2025-12-28 17:31:49,741] Trial 20 finished with value: 0.9458382297399246 and parameters: {'C': 2.459115015992597, 'solver': 'saga', 'tol': 0.000657551714089758, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:50,009] Trial 21 finished with value: 0.9458375017208035 and parameters: {'C': 1.9210341280559742, 'solver': 'saga', 'tol': 0.0006826375256780419, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:50,312] Trial 22 finished with value: 0.9458228392752718 and parameters: {'C': 1.8066707612477446, 'solver': 'saga', 'tol': 0.0007429751368840978, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:50,559] Trial 23 finished with value: 0.9434294371141277 and parameters: {'C': 0.22949903154038645, 'solver': 'saga', 'tol': 0.0011496856742483547, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:50,744] Trial 24 finished with value: 0.937110282713256 and parameters: {'C': 0.035308116237682846, 'solver': 'saga', 'tol': 0.0022965876870089993, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:51,030] Trial 25 finished with value: 0.9457953283531019 and parameters: {'C': 4.141906473286453, 'solver': 'saga', 'tol': 0.00013890685344674638, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:51,214] Trial 26 finished with value: 0.945793526258328 and parameters: {'C': 1.2943402140456932, 'solver': 'saga', 'tol': 0.006655252550470224, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:51,446] Trial 27 finished with value: 0.9442368643404068 and parameters: {'C': 0.3330330545309105, 'solver': 'saga', 'tol': 0.0006080073103057892, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:51,653] Trial 28 finished with value: 0.9456650593061681 and parameters: {'C': 28.20335741618095, 'solver': 'saga', 'tol': 0.0012516744133310553, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:51,882] Trial 29 finished with value: 0.9235982038772249 and parameters: {'C': 0.004669913056751054, 'solver': 'saga', 'tol': 0.00030663034252441075, 'class_weight': None}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:52,079] Trial 30 finished with value: 0.9369950570584091 and parameters: {'C': 0.034041277435138594, 'solver': 'saga', 'tol': 0.005851137109048517, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:52,350] Trial 31 finished with value: 0.9457950660289299 and parameters: {'C': 3.4268754649940685, 'solver': 'saga', 'tol': 0.0001502390551515356, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:52,634] Trial 32 finished with value: 0.9457665622389632 and parameters: {'C': 7.25069132193367, 'solver': 'saga', 'tol': 5.2679075291736016e-05, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:52,902] Trial 33 finished with value: 0.9456644747904783 and parameters: {'C': 57.9709695482232, 'solver': 'saga', 'tol': 0.0002606054369408745, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:53,112] Trial 34 finished with value: 0.9454112142184202 and parameters: {'C': 0.7489304394687303, 'solver': 'saga', 'tol': 0.0010600051499381454, 'class_weight': None}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:53,293] Trial 35 finished with value: 0.9421839116661396 and parameters: {'C': 6.641378163444773, 'solver': 'newton-cg', 'tol': 0.0030507898214290233, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:53,465] Trial 36 finished with value: 0.9457349937133542 and parameters: {'C': 1.8494720324152185, 'solver': 'lbfgs', 'tol': 0.0001787219137701143, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:53,712] Trial 37 finished with value: 0.9456503902265281 and parameters: {'C': 92.10185383082764, 'solver': 'saga', 'tol': 0.0005646776773488995, 'class_weight': None}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:53,928] Trial 38 finished with value: 0.9425040459805749 and parameters: {'C': 0.1570269939324722, 'solver': 'newton-cg', 'tol': 4.4722452443708146e-05, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:54,197] Trial 39 finished with value: 0.9457374253302012 and parameters: {'C': 10.082535140303104, 'solver': 'saga', 'tol': 9.221752095749054e-05, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:54,289] Trial 40 finished with value: 0.904847670939459 and parameters: {'C': 0.04240772908932647, 'solver': 'lbfgs', 'tol': 0.020471446415464105, 'class_weight': None}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:54,553] Trial 41 finished with value: 0.945780366634635 and parameters: {'C': 3.2405074810014325, 'solver': 'saga', 'tol': 0.00017545867602809123, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:54,871] Trial 42 finished with value: 0.9454698451585744 and parameters: {'C': 0.8405752278349372, 'solver': 'saga', 'tol': 0.00013511836969608192, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,071] Trial 43 finished with value: 0.9458093309132769 and parameters: {'C': 2.594374573060991, 'solver': 'saga', 'tol': 0.0021134646108756233, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,285] Trial 44 finished with value: 0.9455768521087041 and parameters: {'C': 14.755453547090305, 'solver': 'saga', 'tol': 0.002502522007978829, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,444] Trial 45 finished with value: 0.9453573691676316 and parameters: {'C': 58.39700302933882, 'solver': 'saga', 'tol': 0.01217575055262904, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,641] Trial 46 finished with value: 0.9407113309697174 and parameters: {'C': 0.09971787641913848, 'solver': 'newton-cg', 'tol': 0.0008406136067697591, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,837] Trial 47 finished with value: 0.9457348255321459 and parameters: {'C': 1.5830400111278367, 'solver': 'saga', 'tol': 0.0017045068300958928, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:55,983] Trial 48 finished with value: 0.9456934232890215 and parameters: {'C': 4.836953455709155, 'solver': 'lbfgs', 'tol': 0.00038224411875424446, 'class_weight': None}. Best is trial 20 with value: 0.9458382297399246.
# [I 2025-12-28 17:31:56,253] Trial 49 finished with value: 0.8299191108828593 and parameters: {'C': 0.00013673190252125339, 'solver': 'saga', 'tol': 0.0006980091508780599, 'class_weight': 'balanced'}. Best is trial 20 with value: 0.9458382297399246.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.945868401774686
#   Params:
#     C: 4.282347334519079
#     solver: saga
#     tol: 0.0008828580509878249
#     class_weight: balanced
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2025-12-28 16:56:09,305] A new study created in memory with name: no-name-11a11048-6b69-46e3-b31b-cb9ff5657cab
# [I 2025-12-28 16:56:09,858] Trial 0 finished with value: 0.9517612195393959 and parameters: {'lambda': 0.009089056364890656, 'alpha': 0.19660564758475982, 'subsample': 0.6016544774389302, 'colsample_bytree': 0.5109367817780526, 'max_depth': 3, 'eta': 0.26070017356685404, 'gamma': 3.3966791519325987, 'scale_pos_weight': 5.421585721701845, 'min_child_weight': 8, 'max_delta_step': 3}. Best is trial 0 with value: 0.9517612195393959.
# [I 2025-12-28 16:56:10,586] Trial 1 finished with value: 0.8618135106489847 and parameters: {'lambda': 0.4062187850674492, 'alpha': 0.018229951871403947, 'subsample': 0.8159347045039758, 'colsample_bytree': 0.4781306926759316, 'max_depth': 6, 'eta': 0.03582842261189745, 'gamma': 2.074448796798568, 'scale_pos_weight': 5.817993566616508, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 0 with value: 0.9517612195393959.
# [I 2025-12-28 16:56:11,241] Trial 2 finished with value: 0.9598657003556653 and parameters: {'lambda': 0.083885076157405, 'alpha': 0.35562897193483967, 'subsample': 0.5026284717796976, 'colsample_bytree': 0.5165454891067146, 'max_depth': 5, 'eta': 0.2107036777053268, 'gamma': 7.313896261049272, 'scale_pos_weight': 4.457689205255163, 'min_child_weight': 5, 'max_delta_step': 9}. Best is trial 2 with value: 0.9598657003556653.
# [I 2025-12-28 16:56:11,810] Trial 3 finished with value: 0.9594539707629565 and parameters: {'lambda': 0.001063707720826273, 'alpha': 2.0050585498629694, 'subsample': 0.7553130242589841, 'colsample_bytree': 0.6390666846233148, 'max_depth': 4, 'eta': 0.28498001402031686, 'gamma': 6.919544971539326, 'scale_pos_weight': 6.4528470009528265, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 2 with value: 0.9598657003556653.
# [I 2025-12-28 16:56:12,383] Trial 4 finished with value: 0.9633644932857951 and parameters: {'lambda': 3.4246711267366856, 'alpha': 1.3196177516863106, 'subsample': 0.8908113128009604, 'colsample_bytree': 0.9721568989032568, 'max_depth': 4, 'eta': 0.2173836338210751, 'gamma': 2.283196973493422, 'scale_pos_weight': 3.208536793659782, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 4 with value: 0.9633644932857951.
# [I 2025-12-28 16:56:13,090] Trial 5 finished with value: 0.967774518898584 and parameters: {'lambda': 0.7013359451778146, 'alpha': 0.00845162811004379, 'subsample': 0.8838753993094037, 'colsample_bytree': 0.9057049160165488, 'max_depth': 9, 'eta': 0.2148723687895777, 'gamma': 4.9634330918920195, 'scale_pos_weight': 8.89799763306697, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 5 with value: 0.967774518898584.
# [I 2025-12-28 16:56:13,899] Trial 6 finished with value: 0.9713669620093855 and parameters: {'lambda': 0.023947223729464485, 'alpha': 0.10809755689321505, 'subsample': 0.7979957805503628, 'colsample_bytree': 0.819712068614967, 'max_depth': 10, 'eta': 0.17639263637112934, 'gamma': 3.2853674275451903, 'scale_pos_weight': 4.963082432432627, 'min_child_weight': 8, 'max_delta_step': 10}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:14,461] Trial 7 finished with value: 0.9465623926404031 and parameters: {'lambda': 0.0011391050946263118, 'alpha': 0.7137844780404281, 'subsample': 0.7138501697738227, 'colsample_bytree': 0.7555089808338119, 'max_depth': 3, 'eta': 0.1340612967445142, 'gamma': 2.823094383511534, 'scale_pos_weight': 3.784056964686471, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:15,023] Trial 8 finished with value: 0.9579374187926776 and parameters: {'lambda': 0.180025636976637, 'alpha': 0.20018238534053176, 'subsample': 0.7030557558441177, 'colsample_bytree': 0.6182881242139961, 'max_depth': 3, 'eta': 0.17218724268852403, 'gamma': 1.1384351284872163, 'scale_pos_weight': 2.052967966543068, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:15,743] Trial 9 finished with value: 0.9648722480480836 and parameters: {'lambda': 6.41033511222544, 'alpha': 1.1841802413692346, 'subsample': 0.6148715102003907, 'colsample_bytree': 0.6924764423158465, 'max_depth': 9, 'eta': 0.1681044946733144, 'gamma': 6.498263132243981, 'scale_pos_weight': 3.8179122597913495, 'min_child_weight': 6, 'max_delta_step': 8}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:16,606] Trial 10 finished with value: 0.9632399174927074 and parameters: {'lambda': 0.01965872479325474, 'alpha': 0.0018464901134717365, 'subsample': 0.9547726394316491, 'colsample_bytree': 0.8279453800187281, 'max_depth': 10, 'eta': 0.09494582293333888, 'gamma': 9.250860631770633, 'scale_pos_weight': 7.915203783134048, 'min_child_weight': 10, 'max_delta_step': 10}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:17,290] Trial 11 finished with value: 0.9671151749594055 and parameters: {'lambda': 0.9166629520805483, 'alpha': 0.01145006837565642, 'subsample': 0.8612823208119595, 'colsample_bytree': 0.9183451491972582, 'max_depth': 8, 'eta': 0.22569940432044, 'gamma': 4.708198679339295, 'scale_pos_weight': 9.333745282056404, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:18,119] Trial 12 finished with value: 0.9655140920076982 and parameters: {'lambda': 0.027525222409790114, 'alpha': 0.030255327775114794, 'subsample': 0.989139094445905, 'colsample_bytree': 0.8638190879290691, 'max_depth': 8, 'eta': 0.1175479431647187, 'gamma': 4.67921585104682, 'scale_pos_weight': 9.472320091932158, 'min_child_weight': 8, 'max_delta_step': 5}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:19,382] Trial 13 finished with value: 0.9662476725825018 and parameters: {'lambda': 1.334438104553577, 'alpha': 0.0015203449303393254, 'subsample': 0.8039573701793037, 'colsample_bytree': 0.797444454259258, 'max_depth': 10, 'eta': 0.07664339869324811, 'gamma': 0.06266654949333228, 'scale_pos_weight': 7.421231402361833, 'min_child_weight': 8, 'max_delta_step': 6}. Best is trial 6 with value: 0.9713669620093855.
# [I 2025-12-28 16:56:20,011] Trial 14 finished with value: 0.9720945793421714 and parameters: {'lambda': 0.08729153021824654, 'alpha': 0.04013317546071849, 'subsample': 0.9222600201605669, 'colsample_bytree': 0.99379509448612, 'max_depth': 8, 'eta': 0.18750113731302093, 'gamma': 4.00589449449879, 'scale_pos_weight': 1.1836555696533115, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 14 with value: 0.9720945793421714.
# [I 2025-12-28 16:56:20,695] Trial 15 finished with value: 0.9722385069899705 and parameters: {'lambda': 0.004769148108003932, 'alpha': 0.05435644018222203, 'subsample': 0.9302584152308335, 'colsample_bytree': 0.9922033956009833, 'max_depth': 8, 'eta': 0.17734174204191905, 'gamma': 3.500572267795907, 'scale_pos_weight': 1.5031159580485243, 'min_child_weight': 5, 'max_delta_step': 10}. Best is trial 15 with value: 0.9722385069899705.
# [I 2025-12-28 16:56:21,243] Trial 16 finished with value: 0.9703839794799792 and parameters: {'lambda': 0.004645829352178328, 'alpha': 0.04758540173201305, 'subsample': 0.9437818429491045, 'colsample_bytree': 0.9631753726396233, 'max_depth': 7, 'eta': 0.2504920773888029, 'gamma': 6.009935509235737, 'scale_pos_weight': 1.0244510581017812, 'min_child_weight': 5, 'max_delta_step': 6}. Best is trial 15 with value: 0.9722385069899705.
# [I 2025-12-28 16:56:21,957] Trial 17 finished with value: 0.9675574842373361 and parameters: {'lambda': 0.08626574509762551, 'alpha': 7.972049366347028, 'subsample': 0.4291175211980552, 'colsample_bytree': 0.9851141460613351, 'max_depth': 7, 'eta': 0.13660483200708662, 'gamma': 3.996841788439346, 'scale_pos_weight': 1.121116310762468, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 15 with value: 0.9722385069899705.
# [I 2025-12-28 16:56:22,810] Trial 18 finished with value: 0.884406110922172 and parameters: {'lambda': 0.0035797765606676362, 'alpha': 0.006772640798463138, 'subsample': 0.9971395317482364, 'colsample_bytree': 0.41127483993301434, 'max_depth': 8, 'eta': 0.015183827389272986, 'gamma': 9.263251148554371, 'scale_pos_weight': 2.0989761550956203, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 15 with value: 0.9722385069899705.
# [I 2025-12-28 16:56:23,505] Trial 19 finished with value: 0.9721345608296453 and parameters: {'lambda': 0.20701307855705392, 'alpha': 0.05518921369957271, 'subsample': 0.924576619820777, 'colsample_bytree': 0.9211152224351867, 'max_depth': 6, 'eta': 0.1893751530774852, 'gamma': 1.4014689599143528, 'scale_pos_weight': 2.125617216181391, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 15 with value: 0.9722385069899705.
# [I 2025-12-28 16:56:24,285] Trial 20 finished with value: 0.9723409389288103 and parameters: {'lambda': 0.04219689429389498, 'alpha': 0.0716595257519865, 'subsample': 0.6022079095825481, 'colsample_bytree': 0.8981799309616186, 'max_depth': 6, 'eta': 0.2942039978011811, 'gamma': 0.8289959398441907, 'scale_pos_weight': 2.277241866784494, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 20 with value: 0.9723409389288103.
# [I 2025-12-28 16:56:24,998] Trial 21 finished with value: 0.9724277849561057 and parameters: {'lambda': 0.007839215718294665, 'alpha': 0.0811867765666327, 'subsample': 0.627595592650533, 'colsample_bytree': 0.9026365037193246, 'max_depth': 6, 'eta': 0.26237273118716037, 'gamma': 0.9695935898388299, 'scale_pos_weight': 2.5976334659760907, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 21 with value: 0.9724277849561057.
# [I 2025-12-28 16:56:25,675] Trial 22 finished with value: 0.9715332175522636 and parameters: {'lambda': 0.007756007718903885, 'alpha': 0.0994089005208407, 'subsample': 0.6148294392914211, 'colsample_bytree': 0.8862030149233371, 'max_depth': 5, 'eta': 0.29764219751812315, 'gamma': 0.04725295859945666, 'scale_pos_weight': 2.829454050962531, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 21 with value: 0.9724277849561057.
# [I 2025-12-28 16:56:26,380] Trial 23 finished with value: 0.970742675861611 and parameters: {'lambda': 0.0025273480497401135, 'alpha': 0.34292291797113894, 'subsample': 0.5467936033360692, 'colsample_bytree': 0.7445339967890012, 'max_depth': 6, 'eta': 0.26588583364723495, 'gamma': 1.0358003266917475, 'scale_pos_weight': 2.8494526499166977, 'min_child_weight': 10, 'max_delta_step': 7}. Best is trial 21 with value: 0.9724277849561057.
# [I 2025-12-28 16:56:27,129] Trial 24 finished with value: 0.973015081076344 and parameters: {'lambda': 0.03966199671232418, 'alpha': 0.004664841487662486, 'subsample': 0.6677302210021138, 'colsample_bytree': 0.8649135372218577, 'max_depth': 7, 'eta': 0.24671201836945736, 'gamma': 1.9453985700395369, 'scale_pos_weight': 1.872968123114736, 'min_child_weight': 7, 'max_delta_step': 6}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:27,782] Trial 25 finished with value: 0.9697881376625359 and parameters: {'lambda': 0.029892003810651026, 'alpha': 0.0039221785868565244, 'subsample': 0.6677950926276494, 'colsample_bytree': 0.7724382901274122, 'max_depth': 5, 'eta': 0.2425949558751303, 'gamma': 0.7316703403349482, 'scale_pos_weight': 3.1508527660681986, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:28,559] Trial 26 finished with value: 0.9717959771278085 and parameters: {'lambda': 0.013023501831472458, 'alpha': 0.003923485409602813, 'subsample': 0.5389588097757, 'colsample_bytree': 0.862313419470845, 'max_depth': 7, 'eta': 0.27763170053116804, 'gamma': 1.9195283699017667, 'scale_pos_weight': 4.140849045579107, 'min_child_weight': 9, 'max_delta_step': 6}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:29,237] Trial 27 finished with value: 0.9721066665525373 and parameters: {'lambda': 0.03783502480938837, 'alpha': 0.017656973290141206, 'subsample': 0.6744530401615696, 'colsample_bytree': 0.7017481037532847, 'max_depth': 6, 'eta': 0.2991856458788448, 'gamma': 2.514175181746174, 'scale_pos_weight': 2.15574673556926, 'min_child_weight': 7, 'max_delta_step': 4}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:30,052] Trial 28 finished with value: 0.9722952546251253 and parameters: {'lambda': 0.03747075293586305, 'alpha': 0.0031306387817501198, 'subsample': 0.45210348680586654, 'colsample_bytree': 0.9404647568633724, 'max_depth': 7, 'eta': 0.2359196805133239, 'gamma': 0.6226513771773429, 'scale_pos_weight': 2.634472600780186, 'min_child_weight': 9, 'max_delta_step': 7}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:30,712] Trial 29 finished with value: 0.9682326020113378 and parameters: {'lambda': 0.010380626130273482, 'alpha': 0.10095148841916227, 'subsample': 0.5930269376334166, 'colsample_bytree': 0.8560786584675885, 'max_depth': 5, 'eta': 0.26238225859647746, 'gamma': 1.4522313043463821, 'scale_pos_weight': 5.210559750547279, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:31,332] Trial 30 finished with value: 0.9614524778381196 and parameters: {'lambda': 0.06074112750963484, 'alpha': 0.21107342182601385, 'subsample': 0.6438871641525459, 'colsample_bytree': 0.7158170229375411, 'max_depth': 4, 'eta': 0.27430127445188685, 'gamma': 2.9609198490515434, 'scale_pos_weight': 5.960283065674689, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:32,108] Trial 31 finished with value: 0.9719594335829139 and parameters: {'lambda': 0.047196655529981056, 'alpha': 0.0034944903401339816, 'subsample': 0.4796742435384931, 'colsample_bytree': 0.9402404785920088, 'max_depth': 7, 'eta': 0.23675044047036925, 'gamma': 0.5991285800415849, 'scale_pos_weight': 2.606195209744567, 'min_child_weight': 9, 'max_delta_step': 7}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:32,823] Trial 32 finished with value: 0.9721515880444208 and parameters: {'lambda': 0.1717843816175182, 'alpha': 0.0011991888859679413, 'subsample': 0.4177106234069387, 'colsample_bytree': 0.9344155934922219, 'max_depth': 6, 'eta': 0.25082713111564137, 'gamma': 1.9062780605057514, 'scale_pos_weight': 1.6344291037685803, 'min_child_weight': 9, 'max_delta_step': 6}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:33,621] Trial 33 finished with value: 0.9716927520122679 and parameters: {'lambda': 0.014953750988203288, 'alpha': 0.014418398882212424, 'subsample': 0.5717594450173634, 'colsample_bytree': 0.8969285122130796, 'max_depth': 7, 'eta': 0.19862098340976403, 'gamma': 0.31662294206314534, 'scale_pos_weight': 3.42453506654916, 'min_child_weight': 9, 'max_delta_step': 8}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:34,389] Trial 34 finished with value: 0.9700654811723024 and parameters: {'lambda': 0.35301211124122717, 'alpha': 0.006742071608559417, 'subsample': 0.47865261878068943, 'colsample_bytree': 0.8117600622057941, 'max_depth': 6, 'eta': 0.23012205815592068, 'gamma': 1.6711360882320876, 'scale_pos_weight': 4.453065067603184, 'min_child_weight': 7, 'max_delta_step': 7}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:35,098] Trial 35 finished with value: 0.9710082957585291 and parameters: {'lambda': 0.04286515607819174, 'alpha': 0.0023558674528585165, 'subsample': 0.7326836114966542, 'colsample_bytree': 0.8472185720728038, 'max_depth': 5, 'eta': 0.2845300695768198, 'gamma': 0.7300207797554222, 'scale_pos_weight': 2.455083358886599, 'min_child_weight': 8, 'max_delta_step': 4}. Best is trial 24 with value: 0.973015081076344.
# [I 2025-12-28 16:56:35,828] Trial 36 finished with value: 0.9730446885561567 and parameters: {'lambda': 0.007775094366346263, 'alpha': 0.02620091832243084, 'subsample': 0.5067124250337527, 'colsample_bytree': 0.9471017712334043, 'max_depth': 7, 'eta': 0.25692615597308216, 'gamma': 2.34953643139851, 'scale_pos_weight': 1.6830619844368866, 'min_child_weight': 6, 'max_delta_step': 6}. Best is trial 36 with value: 0.9730446885561567.
# [I 2025-12-28 16:56:36,527] Trial 37 finished with value: 0.971755630608888 and parameters: {'lambda': 0.0072950490633380905, 'alpha': 0.021236099981182737, 'subsample': 0.532649978491614, 'colsample_bytree': 0.6050439939524338, 'max_depth': 6, 'eta': 0.20572505004431124, 'gamma': 2.7196330658179795, 'scale_pos_weight': 1.7174687054105215, 'min_child_weight': 6, 'max_delta_step': 5}. Best is trial 36 with value: 0.9730446885561567.
# [I 2025-12-28 16:56:37,303] Trial 38 finished with value: 0.973758715941166 and parameters: {'lambda': 0.0014770483947393826, 'alpha': 0.029365934064572812, 'subsample': 0.7667874228961711, 'colsample_bytree': 0.8804456933343452, 'max_depth': 9, 'eta': 0.256193077206768, 'gamma': 2.2537591303829427, 'scale_pos_weight': 3.4270297585826026, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:38,051] Trial 39 finished with value: 0.9725881177403468 and parameters: {'lambda': 0.00201761428345076, 'alpha': 0.025085566981548218, 'subsample': 0.7524553046632628, 'colsample_bytree': 0.5689649050517269, 'max_depth': 9, 'eta': 0.2634864501884865, 'gamma': 2.2525589176022733, 'scale_pos_weight': 3.549332212132966, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:38,766] Trial 40 finished with value: 0.9709894088127653 and parameters: {'lambda': 0.0020299798885168962, 'alpha': 0.027424146599747713, 'subsample': 0.7490115865271544, 'colsample_bytree': 0.5480165647467345, 'max_depth': 9, 'eta': 0.22037795027057652, 'gamma': 3.596347611293109, 'scale_pos_weight': 3.5277307046522437, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:39,513] Trial 41 finished with value: 0.9728060160391893 and parameters: {'lambda': 0.0014003000244583702, 'alpha': 0.008982700954563811, 'subsample': 0.8324558733007796, 'colsample_bytree': 0.5577899734492614, 'max_depth': 9, 'eta': 0.2581627670991713, 'gamma': 2.2628104214302773, 'scale_pos_weight': 4.4884684712397505, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:40,271] Trial 42 finished with value: 0.9721029317151721 and parameters: {'lambda': 0.0014797051995714741, 'alpha': 0.008899687826317716, 'subsample': 0.8428043923110609, 'colsample_bytree': 0.5654517184979521, 'max_depth': 9, 'eta': 0.2522780919188828, 'gamma': 2.295126869197729, 'scale_pos_weight': 4.573635878011727, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:41,040] Trial 43 finished with value: 0.9721315077643911 and parameters: {'lambda': 0.0010035915332286998, 'alpha': 0.006509873424897991, 'subsample': 0.7779350673499154, 'colsample_bytree': 0.5004052049363401, 'max_depth': 9, 'eta': 0.27752120322241763, 'gamma': 2.204151605043713, 'scale_pos_weight': 5.976326969597118, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:41,793] Trial 44 finished with value: 0.9723802241249325 and parameters: {'lambda': 0.00212171472375119, 'alpha': 0.013509280727590368, 'subsample': 0.8491036750168333, 'colsample_bytree': 0.6573887939803442, 'max_depth': 10, 'eta': 0.21396802951680005, 'gamma': 3.2008901322321694, 'scale_pos_weight': 4.000005525298655, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:42,530] Trial 45 finished with value: 0.9698170700355772 and parameters: {'lambda': 0.0031912125852995733, 'alpha': 0.02698349481420252, 'subsample': 0.7729801298168804, 'colsample_bytree': 0.47653986824747097, 'max_depth': 9, 'eta': 0.24700380254610077, 'gamma': 4.025201495237243, 'scale_pos_weight': 4.6457956010977135, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:43,192] Trial 46 finished with value: 0.9696992748347606 and parameters: {'lambda': 0.0017280650248088626, 'alpha': 0.011386850033657444, 'subsample': 0.821643423210176, 'colsample_bytree': 0.5792581543947115, 'max_depth': 8, 'eta': 0.27014571606912624, 'gamma': 5.389114607898266, 'scale_pos_weight': 3.133817897917283, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:43,792] Trial 47 finished with value: 0.9667218301147167 and parameters: {'lambda': 0.004884084977571024, 'alpha': 0.0348416372794575, 'subsample': 0.887022333459425, 'colsample_bytree': 0.6358245560720351, 'max_depth': 10, 'eta': 0.28566314502025913, 'gamma': 7.961987004014087, 'scale_pos_weight': 5.058607338583162, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:44,603] Trial 48 finished with value: 0.9700200204188741 and parameters: {'lambda': 0.0015373782178562132, 'alpha': 0.00520023986372842, 'subsample': 0.7421706483954212, 'colsample_bytree': 0.48032840448676767, 'max_depth': 9, 'eta': 0.22767560736942122, 'gamma': 2.8187781184264535, 'scale_pos_weight': 6.8489214191919014, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 38 with value: 0.973758715941166.
# [I 2025-12-28 16:56:45,435] Trial 49 finished with value: 0.9691130750493726 and parameters: {'lambda': 0.002837172054776374, 'alpha': 0.020779558127352327, 'subsample': 0.6911142435653193, 'colsample_bytree': 0.4026412049144538, 'max_depth': 8, 'eta': 0.1988246984854678, 'gamma': 1.582439302061892, 'scale_pos_weight': 5.594240156921766, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 38 with value: 0.973758715941166.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.973758715941166
#   Params:
#     lambda: 0.0014770483947393826
#     alpha: 0.029365934064572812
#     subsample: 0.7667874228961711
#     colsample_bytree: 0.8804456933343452
#     max_depth: 9
#     eta: 0.256193077206768
#     gamma: 2.2537591303829427
#     scale_pos_weight: 3.4270297585826026
#     min_child_weight: 5
#     max_delta_step: 2
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97     11423
#            1       0.68      0.88      0.76      1074
#
#     accuracy                           0.95     12497
#    macro avg       0.83      0.92      0.87     12497
# weighted avg       0.96      0.95      0.96     12497

# %% [markdown]
# ## Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.16108007, 0.16108007, 0.17690875]),
#  array([       inf, 1.        , 0.99946015, 0.99945962, 0.99934002]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.9836759805880227

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.531
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.531       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.485
# std        0.183
# min        0.212
# 25%        0.316
# 50%        0.467
# 75%        0.641
# max        0.819
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
# C:\Users\sree varshan\AppData\Local\Temp\ipykernel_9796\4037021561.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.212  10.000    1239.000
# 8       8                0.212                0.819 160.000    1090.000
# 9       9                0.821                1.000 899.000     351.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.029   5.000    1245.000
# 7       7                0.029                0.212  10.000    1239.000
# 8       8                0.212                0.819 160.000    1090.000
# 9       9                0.821                1.000 899.000     351.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.801          99.199
# 8      12.800          87.200
# 9      71.920          28.080

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 899.000     351.000
# 1       8                0.212                0.819 160.000    1090.000
# 2       7                0.029                0.212  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.920          28.080
# 1      12.800          87.200
# 2       0.801          99.199
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 899.000     351.000
# 1       8                0.212                0.819 160.000    1090.000
# 2       7                0.029                0.212  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.920          28.080     899.000         351.000
# 1      12.800          87.200    1059.000        1441.000
# 2       0.801          99.199    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 899.000     351.000
# 1       8                0.212                0.819 160.000    1090.000
# 2       7                0.029                0.212  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.800          87.200    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.073
# 1              12.615
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 899.000     351.000
# 1       8                0.212                0.819 160.000    1090.000
# 2       7                0.029                0.212  10.000    1239.000
# 3       6                0.004                0.029   5.000    1245.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.800          87.200    1059.000        1441.000          98.603
# 2       0.801          99.199    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.073 80.633
# 1              12.615 85.988
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9836759805880227
# Gini Coefficient: 0.9673519611760455

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# #### Finalize The Model and Visualize Feature Importance

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
import os
from joblib import dump

# Create folder if it doesn't exist
os.makedirs('sreevarshan', exist_ok=True)

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}

# Now dump safely
dump(model_data, 'sreevarshan/model_data.joblib')
# Out:
# ['sreevarshan/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[ 0.01482806,  0.63694565,  1.18729214, 16.00936351, 17.56905094,
#          13.78908904,  2.05169781, -1.84745743,  1.86092918,  1.00124214,
#          -3.51282536,  1.06388594,  1.06388594]]),
#  array([-20.91384764]))
